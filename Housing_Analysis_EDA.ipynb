# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv("Nashville Housing.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56477 entries, 0 to 56476
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UniqueID         56477 non-null  int64
#  1   ParcelID         56477 non-null  object
#  2   LandUse          56477 non-null  object
#  3   PropertyAddress  56448 non-null  object
#  4   SaleDate         56477 non-null  object
#  5   SalePrice        56477 non-null  object
#  6   LegalReference   56477 non-null  object
#  7   SoldAsVacant     56477 non-null  object
#  8   OwnerName        25261 non-null  object
#  9   OwnerAddress     26015 non-null  object
#  10  Acreage          26015 non-null  float64
#  11  TaxDistrict      26015 non-null  object
#  12  LandValue        26015 non-null  float64
#  13  BuildingValue    26015 non-null  float64
#  14  TotalValue       26015 non-null  float64
#  15  YearBuilt        24163 non-null  float64
# ...

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23705 entries, 0 to 54214
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UniqueID         23705 non-null  int64
#  1   ParcelID         23705 non-null  object
#  2   LandUse          23705 non-null  object
#  3   PropertyAddress  23705 non-null  object
#  4   SaleDate         23705 non-null  object
#  5   SalePrice        23705 non-null  object
#  6   LegalReference   23705 non-null  object
#  7   SoldAsVacant     23705 non-null  object
#  8   OwnerName        23705 non-null  object
#  9   OwnerAddress     23705 non-null  object
#  10  Acreage          23705 non-null  float64
#  11  TaxDistrict      23705 non-null  object
#  12  LandValue        23705 non-null  float64
#  13  BuildingValue    23705 non-null  float64
#  14  TotalValue       23705 non-null  float64
#  15  YearBuilt        23705 non-null  float64
# ...

# %%
df['SaleDate']
# Out:
# 0             April 9, 2013
# 1             June 10, 2014
# 2        September 26, 2016
# 3          January 29, 2016
# 4          October 10, 2014
#                 ...
# 54210          July 8, 2016
# 54211         July 27, 2015
# 54212     September 5, 2014
# 54213     November 24, 2014
# 54214     November 12, 2014
# Name: SaleDate, Length: 23705, dtype: object

# %%
df['SalePrice'].max()
# Out:
# '99999'

# %%
df['SalePrice'].describe()
# Out:
# count      23705
# unique      3764
# top       150000
# freq         256
# Name: SalePrice, dtype: object

# %%
df.describe()
# Out:
#           UniqueID        Acreage     LandValue  BuildingValue    TotalValue  \
# count  23705.000000  23705.000000  2.370500e+04   2.370500e+04  2.370500e+04
# mean   27584.465260      0.455836  6.904970e+04   1.730583e+05  2.447819e+05
# std    16549.621489      0.793932  1.021612e+05   1.935828e+05  2.723682e+05
# min        1.000000      0.040000  1.000000e+02   1.400000e+03  1.260000e+04
# 25%    13068.000000      0.190000  2.200000e+04   8.390000e+04  1.098000e+05
# 50%    27214.000000      0.270000  2.990000e+04   1.176000e+05  1.548000e+05
# 75%    42016.000000      0.450000  6.030000e+04   1.892000e+05  2.782000e+05
# max    56615.000000     47.500000  1.869000e+06   5.824300e+06  6.402600e+06
#
#           YearBuilt      Bedrooms      FullBath      HalfBath
# count  23705.000000  23705.000000  23705.000000  23705.000000
# mean    1963.723139      3.094115      1.896984      0.286648
# std       26.385627      0.850667      0.955172      0.489565
# ...

# %%
df['SaleDate'] = pd.to_datetime(df['SaleDate'])

# %%
plt.figure(figsize=(16,10))
plt.yticks(ticks=range(0,10000000,100000))

sns.scatterplot(data=df,x='SaleDate',y='SalePrice',hue='Bedrooms',palette='RdYlGn')
# Out:
# <AxesSubplot:xlabel='SaleDate', ylabel='SalePrice'>

# %%
plt.figure(figsize=(16,10))
plt.yticks(ticks=range(0,10000000,500000))

sns.scatterplot(data=df,x='SaleDate',y='TotalValue',hue='Bedrooms',palette='RdYlGn')
# Out:
# <AxesSubplot:xlabel='SaleDate', ylabel='TotalValue'>

# %%
df.head()
# Out:
#    UniqueID          ParcelID        LandUse  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY
# 1      16918  007 00 0 130.00  SINGLE FAMILY
# 2      54582  007 00 0 138.00  SINGLE FAMILY
# 3      43070  007 00 0 143.00  SINGLE FAMILY
# 4      22714  007 00 0 149.00  SINGLE FAMILY
#
#                       PropertyAddress   SaleDate SalePrice    LegalReference  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09    240000  20130412-0036474
# 1  1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10    366000  20140619-0053768
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26    435000  20160927-0101718
# 3  1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29    255000  20160129-0008913
# 4  1829  FOX CHASE DR, GOODLETTSVILLE 2014-10-10    278000  20141015-0095255
#
#   SoldAsVacant                           OwnerName  \
# 0           No           FRAZIER, CYRENTHA LYNETTE
# 1           No             BONER, CHARLES & LESLIE
# 2           No           WILSON, JAMES E. & JOANNE
# ...

# %%
df.groupby(['SoldAsVacant']).sum()
# Out:
#               UniqueID    Acreage     LandValue  BuildingValue    TotalValue  \
# SoldAsVacant
# N               2351104     38.33  2.706600e+06   1.479600e+07  1.756620e+07
# No            643543044  10566.85  1.594706e+09   3.935428e+09  5.591618e+09
# Y                335109      7.14  4.886000e+05   2.151500e+06  2.663300e+06
# Yes             7660492    193.28  3.892210e+07   1.499708e+08  1.907071e+08
#
#                YearBuilt  Bedrooms  FullBath  HalfBath
# SoldAsVacant
# N               293710.0     412.0     242.0      33.0
# No            45431939.0   71483.0   43614.0    6466.0
# Y                41265.0      64.0      36.0       0.0
# Yes             783143.0    1387.0    1076.0     296.0

# %%
df['LandValue'] = df['LandValue'].astype(float)
df['BuildingValue'] = df['BuildingValue'].astype(float)
df['TotalValue'] = df['TotalValue'].astype(float)

# %%
df.groupby(['SoldAsVacant']).sum()
# Out:
#               UniqueID    Acreage     LandValue  BuildingValue    TotalValue  \
# SoldAsVacant
# N               2351104     38.33  2.706600e+06   1.479600e+07  1.756620e+07
# No            643543044  10566.85  1.594706e+09   3.935428e+09  5.591618e+09
# Y                335109      7.14  4.886000e+05   2.151500e+06  2.663300e+06
# Yes             7660492    193.28  3.892210e+07   1.499708e+08  1.907071e+08
#
#                YearBuilt  Bedrooms  FullBath  HalfBath
# SoldAsVacant
# N               293710.0     412.0     242.0      33.0
# No            45431939.0   71483.0   43614.0    6466.0
# Y                41265.0      64.0      36.0       0.0
# Yes             783143.0    1387.0    1076.0     296.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23705 entries, 0 to 54214
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UniqueID         23705 non-null  int64
#  1   ParcelID         23705 non-null  object
#  2   LandUse          23705 non-null  object
#  3   PropertyAddress  23705 non-null  object
#  4   SaleDate         23705 non-null  datetime64[ns]
#  5   SalePrice        23705 non-null  object
#  6   LegalReference   23705 non-null  object
#  7   SoldAsVacant     23705 non-null  object
#  8   OwnerName        23705 non-null  object
#  9   OwnerAddress     23705 non-null  object
#  10  Acreage          23705 non-null  float64
#  11  TaxDistrict      23705 non-null  object
#  12  LandValue        23705 non-null  float64
#  13  BuildingValue    23705 non-null  float64
#  14  TotalValue       23705 non-null  float64
#  15  YearBuilt        23705 non-null  float64
# ...

# %%
lambda_func = lambda s:s[0]

# %%
lambda_func('askjlgkj')
# Out:
# 'a'

# %%
numbers = [1, 2, 3, 4, 5]
operations = [lambda x: x**2, lambda x: x**3, lambda x: x**4]
result = [op(1.05) for op in operations]
print(result)  # Output: [4, 8, 16]
# Out:
# [1.1025, 1.1576250000000001, 1.2155062500000002]

# %%
df['TaxDistrict'].unique()
# Out:
# array(['GENERAL SERVICES DISTRICT', 'CITY OF GOODLETTSVILLE',
#        'URBAN SERVICES DISTRICT', 'CITY OF BELLE MEADE',
#        'CITY OF BERRY HILL', 'CITY OF OAK HILL', 'CITY OF FOREST HILLS'],
#       dtype=object)

# %%
df.drop('TaxDistrict',inplace=True,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23705 entries, 0 to 54214
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UniqueID         23705 non-null  int64
#  1   ParcelID         23705 non-null  object
#  2   LandUse          23705 non-null  object
#  3   PropertyAddress  23705 non-null  object
#  4   SaleDate         23705 non-null  datetime64[ns]
#  5   SalePrice        23705 non-null  object
#  6   LegalReference   23705 non-null  object
#  7   SoldAsVacant     23705 non-null  object
#  8   OwnerName        23705 non-null  object
#  9   OwnerAddress     23705 non-null  object
#  10  Acreage          23705 non-null  float64
#  11  LandValue        23705 non-null  float64
#  12  BuildingValue    23705 non-null  float64
#  13  TotalValue       23705 non-null  float64
#  14  YearBuilt        23705 non-null  float64
#  15  Bedrooms         23705 non-null  float64
# ...

# %%
df = df.drop(['ParcelID','LandUse','PropertyAddress','LegalReference','SoldAsVacant','OwnerName','OwnerAddress'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23705 entries, 0 to 54214
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   UniqueID       23705 non-null  int64
#  1   SaleDate       23705 non-null  datetime64[ns]
#  2   SalePrice      23705 non-null  object
#  3   Acreage        23705 non-null  float64
#  4   LandValue      23705 non-null  float64
#  5   BuildingValue  23705 non-null  float64
#  6   TotalValue     23705 non-null  float64
#  7   YearBuilt      23705 non-null  float64
#  8   Bedrooms       23705 non-null  float64
#  9   FullBath       23705 non-null  float64
#  10  HalfBath       23705 non-null  float64
# dtypes: datetime64[ns](1), float64(8), int64(1), object(1)
# memory usage: 2.7+ MB

# %%
df['SalePrice'].value_counts()
# Out:
# 150000    256
# 120000    228
# 130000    227
# 125000    226
# 135000    219
#          ...
# 80200       1
# 272900      1
# 177600      1
# 221600      1
# 237900      1
# Name: SalePrice, Length: 3764, dtype: int64

# %%
array = df['SalePrice']

# %%
df['SalePrice'] = df['']

# %%
for i in range(len(array)):
    new_array = array[i].replace(",", "")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2131, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2140, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 10
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df['SalePrice']
# Out:
# 0        240000
# 1        366000
# 2        435000
# 3        255000
# 4        278000
#           ...
# 54210    258000
# 54211    339528
# 54212    230000
# 54213    237900
# 54214    259000
# Name: SalePrice, Length: 23705, dtype: object

# %%
df['SalePrice'] = pd.to_numeric(df['SalePrice'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2315, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "120,000"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [79], in <cell line: 1>()
# ----> 1 df['SalePrice'] = pd.to_numeric(df['SalePrice'])
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\tools\numeric.py:184, in to_numeric(arg, errors, downcast)
#     182 coerce_numeric = errors not in ("ignore", "raise")
#     183 try:
# --> 184     values, _ = lib.maybe_convert_numeric(
#     185         values, set(), coerce_numeric=coerce_numeric
#     186     )
#     187 except (ValueError, TypeError):
#     188     if errors == "raise":
#
# ...

# %%
len(df['SalePrice'])
# Out:
# 23705

# %%
df['SalePrice'] = df['SalePrice'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [54], in <cell line: 1>()
# ----> 1 df['SalePrice'] = df['SalePrice'].astype(float)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...
